# %%
# !nvidia-smi
# Out:
# Tue Nov 11 20:54:13 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-80GB          Off |   00000000:00:05.0 Off |                    0 |
# | N/A   32C    P0             57W /  400W |       0MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
# Clone your GitHub repo
# !git clone https://github.com/Rachel-Fan/Pytorch-UNet-Seagrass.git
# Out:
# Cloning into 'Pytorch-UNet-Seagrass'...
# remote: Enumerating objects: 663, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 663 (delta 24), reused 40 (delta 16), pack-reused 615 (from 1)
# Receiving objects: 100% (663/663), 47.49 MiB | 13.33 MiB/s, done.
# Resolving deltas: 100% (355/355), done.

# %%
# %cd Pytorch-UNet-Seagrass
# Out:
# /content/Pytorch-UNet-Seagrass

# %%
# !ls
# Out:
# data		      predict-pretrain.py  train-update-fast-ddp.py
# Dockerfile	      predict.py	   train-update-fast-folder.py
# env.yaml	      predict-scratch.py   train_update_fast.py
# eval-test-dataset.py  predict-update.py    train_update.py
# evaluate.py	      README.md		   unet
# hubconf.py	      requirements.txt	   utils
# LICENSE		      scripts
# predict-imagenet.py   train.py

# %%
# !pip install --upgrade torch==2.4.0 torchvision==0.19.0 torchaudio==2.4.0 --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 799.0/799.0 MB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 66.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 63.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 56.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 45.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 63.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 18.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 34.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 19.1 MB/s eta 0:00:00
# ...

# %%
import torch

# ✅ 启用 TF32 加速（A100/L4 建议开启）
torch.backends.cuda.matmul.allow_tf32 = True
torch.backends.cudnn.allow_tf32 = True

print("TF32 enabled:", torch.backends.cuda.matmul.allow_tf32)
print("cuDNN TF32 enabled:", torch.backends.cudnn.allow_tf32)
print("CUDA device:", torch.cuda.get_device_name(0))
# Out:
# TF32 enabled: True
# cuDNN TF32 enabled: True
# CUDA device: NVIDIA A100-SXM4-80GB

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# data		      predict-pretrain.py  train-orig.py
# Dockerfile	      predict.py	   train.py
# env.yaml	      predict-scratch.py   train-update-fast-ddp.py
# eval-test-dataset.py  predict-update.py    train-update-fast-folder.py
# evaluate.py	      README.md		   train_update_fast.py
# hubconf.py	      requirements.txt	   train_update.py
# LICENSE		      scripts		   unet
# predict-imagenet.py   train-colab.py	   utils

# %% [markdown]
# # Train on Full dataset

# %%
# !python train-colab-early.py \
  --base-dir "/content/drive/MyDrive/Drone AI/DroneVision_Model_data/All" \
  --out-root "/content/drive/MyDrive/Drone AI/ModelRuns/UNet/All/train_full_1" \
  --epochs 50 --batch-size 8 --accum-steps 2
# Out:
# [loss] pos_weight ≈ 2.00 (r=0.53400)
# [rank 0] device=cuda | BASE_DIR=/content/drive/MyDrive/Drone AI/DroneVision_Model_data/All
# [data] train=9464  valid=2700  | img_size=512
# [train] bs=8, accum=2, lr=0.0003, wd=0.0001
# Epoch 1/50: train_loss=1.6330 | val_dice=0.2770 | val_mIoU=0.2972 | lr=5.07e-07
#   ✅ New best! Saved to /content/drive/MyDrive/Drone AI/ModelRuns/UNet/All/train_full_1/checkpoints/best.pth (val_dice=0.2770)
# Epoch 2/50: train_loss=1.5714 | val_dice=0.2839 | val_mIoU=0.3014 | lr=5.07e-07
#   ✅ New best! Saved to /content/drive/MyDrive/Drone AI/ModelRuns/UNet/All/train_full_1/checkpoints/best.pth (val_dice=0.2839)
# Epoch 3/50: train_loss=1.5357 | val_dice=0.2916 | val_mIoU=0.2962 | lr=5.07e-07
#   ✅ New best! Saved to /content/drive/MyDrive/Drone AI/ModelRuns/UNet/All/train_full_1/checkpoints/best.pth (val_dice=0.2916)
# Epoch 4/50: train_loss=1.5149 | val_dice=0.2952 | val_mIoU=0.2917 | lr=5.07e-07
# ...

# %%
# !python train-colab-early.py \
  --base-dir "/content/drive/MyDrive/Drone AI/DroneVision_Model_data/AK" \
  --out-root "/content/drive/MyDrive/Drone AI/ModelRuns/UNet/AK/train_full_1" \
  --epochs 50 --batch-size 8 --accum-steps 2
# Out:
# [loss] pos_weight ≈ 2.00 (r=0.59250)
# [rank 0] device=cuda | BASE_DIR=/content/drive/MyDrive/Drone AI/DroneVision_Model_data/AK
# [data] train=8528  valid=2436  | img_size=512
# [train] bs=8, accum=2, lr=0.0003, wd=0.0001
# Epoch 1/50: train_loss=1.6342 | val_dice=0.3085 | val_mIoU=0.3230 | lr=5.63e-07
#   ✅ New best! Saved to /content/drive/MyDrive/Drone AI/ModelRuns/UNet/AK/train_full_1/checkpoints/best.pth (val_dice=0.3085)
# Epoch 2/50: train_loss=1.5303 | val_dice=0.3330 | val_mIoU=0.3361 | lr=5.63e-07
#   ✅ New best! Saved to /content/drive/MyDrive/Drone AI/ModelRuns/UNet/AK/train_full_1/checkpoints/best.pth (val_dice=0.3330)
# Epoch 3/50: train_loss=1.4613 | val_dice=0.3397 | val_mIoU=0.3498 | lr=5.63e-07
#   ✅ New best! Saved to /content/drive/MyDrive/Drone AI/ModelRuns/UNet/AK/train_full_1/checkpoints/best.pth (val_dice=0.3397)
# Epoch 4/50: train_loss=1.4140 | val_dice=0.3480 | val_mIoU=0.3554 | lr=5.63e-07
# ...

# %%
# !python train-colab-early.py \
  --base-dir "/content/drive/MyDrive/Drone AI/DroneVision_Model_data/BB" \
  --out-root "/content/drive/MyDrive/Drone AI/ModelRuns/UNet/BB/train_full_1" \
  --epochs 50 --batch-size 8 --accum-steps 2
# Out:
# [loss] pos_weight ≈ 2.57 (r=0.38950)
# [rank 0] device=cuda | BASE_DIR=/content/drive/MyDrive/Drone AI/DroneVision_Model_data/BB
# [data] train=22498  valid=6428  | img_size=512
# [train] bs=8, accum=2, lr=0.0003, wd=0.0001
# Epoch 1/50: train_loss=1.7929 | val_dice=0.1618 | val_mIoU=0.1414 | lr=3.00e-07
#   ✅ New best! Saved to /content/drive/MyDrive/Drone AI/ModelRuns/UNet/BB/train_full_1/checkpoints/best.pth (val_dice=0.1618)
# Epoch 2/50: train_loss=1.7410 | val_dice=0.1577 | val_mIoU=0.1228 | lr=3.00e-07
# Epoch 3/50: train_loss=1.6732 | val_dice=0.1537 | val_mIoU=0.1026 | lr=3.00e-07
# Epoch 4/50: train_loss=1.6337 | val_dice=0.1514 | val_mIoU=0.0856 | lr=3.00e-07
# Epoch 5/50: train_loss=1.6070 | val_dice=0.1490 | val_mIoU=0.0746 | lr=3.00e-07
# Epoch 6/50: train_loss=1.5868 | val_dice=0.1491 | val_mIoU=0.0814 | lr=3.00e-07
# Epoch 7/50: train_loss=1.5719 | val_dice=0.1497 | val_mIoU=0.0863 | lr=3.00e-07
# ⏹️ Early stopping triggered (patience=6).
# ...

# %%
# !python train-colab-early.py \
  --base-dir "/content/drive/MyDrive/Drone AI/DroneVision_Model_data/BC" \
  --out-root "/content/drive/MyDrive/Drone AI/ModelRuns/UNet/BC/train_full_1" \
  --epochs 50 --batch-size 8 --accum-steps 2
# Out:
# [loss] pos_weight ≈ 2.00 (r=0.58850)
# [rank 0] device=cuda | BASE_DIR=/content/drive/MyDrive/Drone AI/DroneVision_Model_data/BC
# [data] train=2670  valid=763  | img_size=512
# [train] bs=8, accum=2, lr=0.0003, wd=0.0001
# Epoch 1/50: train_loss=1.6292 | val_dice=0.2923 | val_mIoU=0.3042 | lr=1.80e-06
#   ✅ New best! Saved to /content/drive/MyDrive/Drone AI/ModelRuns/UNet/BC/train_full_1/checkpoints/best.pth (val_dice=0.2923)
# Epoch 2/50: train_loss=1.5135 | val_dice=0.3210 | val_mIoU=0.3167 | lr=1.80e-06
#   ✅ New best! Saved to /content/drive/MyDrive/Drone AI/ModelRuns/UNet/BC/train_full_1/checkpoints/best.pth (val_dice=0.3210)
# Epoch 3/50: train_loss=1.4275 | val_dice=0.3264 | val_mIoU=0.3273 | lr=1.80e-06
#   ✅ New best! Saved to /content/drive/MyDrive/Drone AI/ModelRuns/UNet/BC/train_full_1/checkpoints/best.pth (val_dice=0.3264)
# Epoch 4/50: train_loss=1.3828 | val_dice=0.3369 | val_mIoU=0.3376 | lr=1.80e-06
# ...

# %%
# !python train-colab-early.py \
  --base-dir "/content/drive/MyDrive/Drone AI/DroneVision_Model_data/OR" \
  --out-root "/content/drive/MyDrive/Drone AI/ModelRuns/UNet/OR/train_nonempty_2" \
  --train-split "/content/drive/MyDrive/Drone AI/DroneVision_Model_data/OR/splits/train_non_empty.txt" \
  --valid-split "/content/drive/MyDrive/Drone AI/DroneVision_Model_data/OR/splits/valid_non_empty.txt" \
  --epochs 50 --batch-size 8 --accum-steps 2
# Out:
# [loss] pos_weight ≈ 7.78 (r=0.12850)
# [rank 0] device=cuda | BASE_DIR=/content/drive/MyDrive/Drone AI/DroneVision_Model_data/OR
# [data] train=12754  valid=1114  | img_size=512
# [train] bs=8, accum=2, lr=0.0003, wd=0.0001
# Epoch 1/50: train_loss=2.0499 | val_dice=0.1701 | val_mIoU=0.1901 | lr=3.76e-07
#   ✅ New best! Saved to /content/drive/MyDrive/Drone AI/ModelRuns/UNet/OR/train_nonempty_2/checkpoints/best.pth (val_dice=0.1701)
# Epoch 2/50: train_loss=2.0218 | val_dice=0.1753 | val_mIoU=0.1906 | lr=3.76e-07
#   ✅ New best! Saved to /content/drive/MyDrive/Drone AI/ModelRuns/UNet/OR/train_nonempty_2/checkpoints/best.pth (val_dice=0.1753)
# Epoch 3/50: train_loss=1.9970 | val_dice=0.1808 | val_mIoU=0.1894 | lr=3.76e-07
#   ✅ New best! Saved to /content/drive/MyDrive/Drone AI/ModelRuns/UNet/OR/train_nonempty_2/checkpoints/best.pth (val_dice=0.1808)
# Epoch 4/50: train_loss=1.9710 | val_dice=0.1841 | val_mIoU=0.1917 | lr=3.76e-07
# ...

# %%
# !python train-colab-early.py \
  --base-dir "/content/drive/MyDrive/Drone AI/DroneVision_Model_data/WA" \
  --out-root "/content/drive/MyDrive/Drone AI/ModelRuns/UNet/WA/train_full_1" \
  --epochs 50 --batch-size 8 --accum-steps 2
# Out:
# [loss] pos_weight ≈ 2.17 (r=0.46050)
# [rank 0] device=cuda | BASE_DIR=/content/drive/MyDrive/Drone AI/DroneVision_Model_data/WA
# [data] train=11787  valid=3367  | img_size=512
# [train] bs=8, accum=2, lr=0.0003, wd=0.0001
# Epoch 1/50: train_loss=1.7503 | val_dice=0.2182 | val_mIoU=0.2308 | lr=4.07e-07
#   ✅ New best! Saved to /content/drive/MyDrive/Drone AI/ModelRuns/UNet/WA/train_full_1/checkpoints/best.pth (val_dice=0.2182)
# Epoch 2/50: train_loss=1.7123 | val_dice=0.2277 | val_mIoU=0.2395 | lr=4.07e-07
#   ✅ New best! Saved to /content/drive/MyDrive/Drone AI/ModelRuns/UNet/WA/train_full_1/checkpoints/best.pth (val_dice=0.2277)
# Epoch 3/50: train_loss=1.6818 | val_dice=0.2362 | val_mIoU=0.2435 | lr=4.07e-07
#   ✅ New best! Saved to /content/drive/MyDrive/Drone AI/ModelRuns/UNet/WA/train_full_1/checkpoints/best.pth (val_dice=0.2362)
# Epoch 4/50: train_loss=1.6581 | val_dice=0.2394 | val_mIoU=0.2413 | lr=4.07e-07
# ...

# %% [markdown]
# # Evaluation on trained checkpoint

# %%
# !python eval-metrics.py \
  --base-dir "/content/drive/MyDrive/Drone AI/DroneVision_Model_data/All" \
  --ckpt "/content/drive/MyDrive/Drone AI/ModelRuns/UNet/All/train_full_1/checkpoints/best.pth" \
  --out-dir "/content/drive/MyDrive/Drone AI/ModelRuns/UNet/All/train_full_1/eval"
# Out:
# [split] Using full split = test
# [split] Using 1293 images in /content/drive/MyDrive/Drone AI/DroneVision_Model_data/All/test/image
# ⚙️ Using local UNet (ckpt=/content/drive/MyDrive/Drone AI/ModelRuns/UNet/All/train_full_1/checkpoints/best.pth)
# Eval: 100% 162/162 [08:23<00:00,  3.11s/it]
#
# 📊 Average Metrics Summary
# ----------------------------------------
# average_iou             : 0.401753
# average_boundary_iou    : 0.142495
# average_accuracy        : 0.743866
# average_dice            : 0.456984
# average_precision       : 0.444268
# average_recall          : 0.600714
# average_hausdorff       : 339.484931
# ----------------------------------------
# Count: 1293 | Split: test | Model: local_unet
#
# ✅ Done.
#   • Per-image: /content/drive/MyDrive/Drone AI/ModelRuns/UNet/All/train_full_1/eval/per_image.csv
# ...

# %%
# !python eval-metrics.py \
  --base-dir "/content/drive/MyDrive/Drone AI/DroneVision_Model_data/AK" \
  --ckpt "/content/drive/MyDrive/Drone AI/ModelRuns/UNet/AK/train_full_1/checkpoints/best.pth" \
  --out-dir "/content/drive/MyDrive/Drone AI/ModelRuns/UNet/AK/train_full_1/eval"
# Out:
# [split] Using full split = test
# [split] Using 1220 images in /content/drive/MyDrive/Drone AI/DroneVision_Model_data/AK/test/image
# ⚙️ Using local UNet (ckpt=/content/drive/MyDrive/Drone AI/ModelRuns/UNet/AK/train_full_1/checkpoints/best.pth)
# Eval: 100% 153/153 [08:32<00:00,  3.35s/it]
#
# 📊 Average Metrics Summary
# ----------------------------------------
# average_iou             : 0.845128
# average_boundary_iou    : 0.372353
# average_accuracy        : 0.880825
# average_dice            : 0.903480
# average_precision       : 0.891068
# average_recall          : 0.943108
# average_hausdorff       : 77.922529
# ----------------------------------------
# Count: 1220 | Split: test | Model: local_unet
#
# ✅ Done.
#   • Per-image: /content/drive/MyDrive/Drone AI/ModelRuns/UNet/AK/train_full_1/eval/per_image.csv
# ...

# %%
# !python eval-metrics.py \
  --base-dir "/content/drive/MyDrive/Drone AI/DroneVision_Model_data/BB" \
  --ckpt "/content/drive/MyDrive/Drone AI/ModelRuns/UNet/BB/train_nonempty_2/checkpoints/best.pth" \
  --out-dir "/content/drive/MyDrive/Drone AI/ModelRuns/UNet/BB/train_nonempty_2/eval_metrics_standalone"
# Out:
# [split] Using full split = test
# [split] Using 3214 images in /content/drive/MyDrive/Drone AI/DroneVision_Model_data/BB/test/image
# ⚙️ Using local UNet (ckpt=/content/drive/MyDrive/Drone AI/ModelRuns/UNet/BB/train_nonempty_2/checkpoints/best.pth)
# Eval: 100% 402/402 [4:36:11<00:00, 41.22s/it]
#
# 📊 Average Metrics Summary
# ----------------------------------------
# average_iou             : 0.488575
# average_boundary_iou    : 0.056514
# average_accuracy        : 0.515928
# average_dice            : 0.638425
# average_precision       : 0.516893
# average_recall          : 0.907371
# average_hausdorff       : 91.758236
# ----------------------------------------
# Count: 3214 | Split: test | Model: local_unet
#
# ✅ Done.
#   • Per-image: /content/drive/MyDrive/Drone AI/ModelRuns/UNet/BB/train_nonempty_2/eval_metrics_standalone/per_image.csv
# ...

# %%
# !python eval-metrics.py \
  --base-dir "/content/drive/MyDrive/Drone AI/DroneVision_Model_data/BC" \
  --ckpt "/content/drive/MyDrive/Drone AI/ModelRuns/UNet/BC/train_full_1/checkpoints/best.pth" \
  --out-dir "/content/drive/MyDrive/Drone AI/ModelRuns/UNet/BC/train_full_1/eval_metrics"
# Out:
# [split] Using full split = test
# [split] Using 382 images in /content/drive/MyDrive/Drone AI/DroneVision_Model_data/BC/test/image
# ⚙️ Using local UNet (ckpt=/content/drive/MyDrive/Drone AI/ModelRuns/UNet/BC/train_full_1/checkpoints/best.pth)
# Eval: 100% 48/48 [01:28<00:00,  1.84s/it]
#
# 📊 Average Metrics Summary
# ----------------------------------------
# average_iou             : 0.843136
# average_boundary_iou    : 0.300195
# average_accuracy        : 0.869766
# average_dice            : 0.907057
# average_precision       : 0.859285
# average_recall          : 0.977334
# average_hausdorff       : 91.886876
# ----------------------------------------
# Count: 382 | Split: test | Model: local_unet
#
# ✅ Done.
#   • Per-image: /content/drive/MyDrive/Drone AI/ModelRuns/UNet/BC/train_full_1/eval_metrics/per_image.csv
# ...

# %%
# !python eval-metrics.py \
  --base-dir "/content/drive/MyDrive/Drone AI/DroneVision_Model_data/OR" \
  --ckpt "/content/drive/MyDrive/Drone AI/ModelRuns/UNet/OR/train_nonempty_2/checkpoints/best.pth" \
  --split-txt "/content/drive/MyDrive/Drone AI/DroneVision_Model_data/OR/splits/test_non_empty.txt" \
  --out-dir "/content/drive/MyDrive/Drone AI/ModelRuns/UNet/OR/train_nonempty_2/evalmetrics-1113"
# Out:
# [split] Using full split = test
# [split] Using 355 images in /content/drive/MyDrive/Drone AI/DroneVision_Model_data/OR/test/image
# ⚙️ Using local UNet (ckpt=/content/drive/MyDrive/Drone AI/ModelRuns/UNet/OR/train_nonempty_2/checkpoints/best.pth)
# Eval: 100% 45/45 [08:49<00:00, 11.76s/it]
#
# 📊 Average Metrics Summary
# ----------------------------------------
# average_iou             : 0.685312
# average_boundary_iou    : 0.107894
# average_accuracy        : 0.729309
# average_dice            : 0.774565
# average_precision       : 0.819748
# average_recall          : 0.792498
# average_hausdorff       : 124.030959
# ----------------------------------------
# Count: 355 | Split: test | Model: local_unet
#
# ✅ Done.
#   • Per-image: /content/drive/MyDrive/Drone AI/ModelRuns/UNet/OR/train_nonempty_2/evalmetrics-1113/per_image.csv
# ...

# %%
# !python eval-metrics.py \
  --base-dir "/content/drive/MyDrive/Drone AI/DroneVision_Model_data/WA" \
  --ckpt "/content/drive/MyDrive/Drone AI/ModelRuns/UNet/WA/train_full_1/checkpoints/best.pth" \
  --out-dir "/content/drive/MyDrive/Drone AI/ModelRuns/UNet/WA/train_full_1/eval"
# Out:
# [split] Using full split = test
# [split] Using 1685 images in /content/drive/MyDrive/Drone AI/DroneVision_Model_data/WA/test/image
# ⚙️ Using local UNet (ckpt=/content/drive/MyDrive/Drone AI/ModelRuns/UNet/WA/train_full_1/checkpoints/best.pth)
# Eval: 100% 211/211 [17:38<00:00,  5.02s/it]
#
# 📊 Average Metrics Summary
# ----------------------------------------
# average_iou             : 0.751722
# average_boundary_iou    : 0.168380
# average_accuracy        : 0.807032
# average_dice            : 0.833579
# average_precision       : 0.860349
# average_recall          : 0.860711
# average_hausdorff       : 96.910147
# ----------------------------------------
# Count: 1685 | Split: test | Model: local_unet
#
# ✅ Done.
#   • Per-image: /content/drive/MyDrive/Drone AI/ModelRuns/UNet/WA/train_full_1/eval/per_image.csv
# ...

# %% [markdown]
# # Evaluation on pretrained model

# %%
# !pip install -q segmentation-models-pytorch
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 7.5 MB/s eta 0:00:00

# %%
# !python eval-pretrain.py \
    --base-dir "/content/drive/MyDrive/Drone AI/DroneVision_Model_data/All" \
    --out-dir "/content/drive/MyDrive/Drone AI/ModelRuns/UNet/All/pretrain/evaleval_1112" \
    --batch-size 32 --img-size 512
# Out:
# [split] Using split = test
# ⚙️ Using SMP Unet (resnet34, imagenet) as pretrained baseline
# Eval: 100% 41/41 [03:21<00:00,  4.92s/it]
#
# ✅ Saved per-image metrics → /content/drive/MyDrive/Drone AI/ModelRuns/UNet/All/pretrain/evaleval_1112/test_detailed_metrics_smp.csv
# ✅ Saved summary JSON     → /content/drive/MyDrive/Drone AI/ModelRuns/UNet/All/pretrain/evaleval_1112/test_summary_smp.json
#
# —— Summary ——
#            average_iou: 0.144043
#   average_boundary_iou: 0.030594
#       average_accuracy: 0.490761
#           average_dice: 0.219953
#      average_precision: 0.381791
#         average_recall: 0.240375

# %%
# !python eval-pretrain.py \
    --base-dir "/content/drive/MyDrive/Drone AI/DroneVision_Model_data/AK" \
    --out-dir "/content/drive/MyDrive/Drone AI/ModelRuns/UNet/AK/pretrain/evaleval_1112" \
    --batch-size 32 --img-size 512
# Out:
# [split] Using split = test
# ⚙️ Using SMP Unet (resnet34, imagenet) as pretrained baseline
# Eval: 100% 39/39 [03:46<00:00,  5.80s/it]
#
# ✅ Saved per-image metrics → /content/drive/MyDrive/Drone AI/ModelRuns/UNet/AK/pretrain/evaleval_1112/test_detailed_metrics_smp.csv
# ✅ Saved summary JSON     → /content/drive/MyDrive/Drone AI/ModelRuns/UNet/AK/pretrain/evaleval_1112/test_summary_smp.json
#
# —— Summary ——
#            average_iou: 0.012617
#   average_boundary_iou: 0.015252
#       average_accuracy: 0.218704
#           average_dice: 0.024471
#      average_precision: 0.744036
#         average_recall: 0.012762

# %%
# !python eval-pretrain.py \
    --base-dir "/content/drive/MyDrive/Drone AI/DroneVision_Model_data/BB" \
    --out-dir "/content/drive/MyDrive/Drone AI/ModelRuns/UNet/BB/pretrain/evaleval_1112" \
    --batch-size 32 --img-size 512
# Out:
# [split] Using split = test
# ⚙️ Using SMP Unet (resnet34, imagenet) as pretrained baseline
# Eval: 100% 101/101 [00:54<00:00,  1.84it/s]
#
# ✅ Saved per-image metrics → /content/drive/MyDrive/Drone AI/ModelRuns/UNet/BB/pretrain/evaleval_1112/test_detailed_metrics_smp.csv
# ✅ Saved summary JSON     → /content/drive/MyDrive/Drone AI/ModelRuns/UNet/BB/pretrain/evaleval_1112/test_summary_smp.json
#
# —— Summary ——
#            average_iou: 0.032151
#   average_boundary_iou: 0.041623
#       average_accuracy: 0.481373
#           average_dice: 0.060789
#      average_precision: 0.472055
#         average_recall: 0.035180

# %%
# !python eval-pretrain.py \
    --base-dir "/content/drive/MyDrive/Drone AI/DroneVision_Model_data/BC" \
    --out-dir "/content/drive/MyDrive/Drone AI/ModelRuns/UNet/BC/pretrain/evaleval_1113" \
    --batch-size 32 --img-size 512
# Out:
# [split] Using split = test
# ⚙️ Using SMP Unet (resnet34, imagenet) as pretrained baseline
# Eval: 100% 12/12 [00:55<00:00,  4.63s/it]
#
# ✅ Saved per-image metrics → /content/drive/MyDrive/Drone AI/ModelRuns/UNet/BC/pretrain/evaleval_1113/test_detailed_metrics_smp.csv
# ✅ Saved summary JSON     → /content/drive/MyDrive/Drone AI/ModelRuns/UNet/BC/pretrain/evaleval_1113/test_summary_smp.json
#
# —— Summary ——
#            average_iou: 0.003791
#   average_boundary_iou: 0.007145
#       average_accuracy: 0.238050
#           average_dice: 0.007553
#      average_precision: 0.731366
#         average_recall: 0.003798

# %%
# !python eval-pretrain.py \
    --base-dir "/content/drive/MyDrive/Drone AI/DroneVision_Model_data/OR" \
    --split-txt "/content/drive/MyDrive/Drone AI/DroneVision_Model_data/OR/splits/test_non_empty.txt" \
    --out-dir "/content/drive/MyDrive/Drone AI/ModelRuns/UNet/OR/pretrain/eval_1112" \
    --batch-size 32 --img-size 512
# Out:
# [split] Using split = test
# [subset] Using subset from /content/drive/MyDrive/Drone AI/DroneVision_Model_data/OR/splits/test_non_empty.txt
# ⚙️ Using SMP Unet (resnet34, imagenet) as pretrained baseline
# Eval: 100% 12/12 [03:54<00:00, 19.57s/it]
#
# ✅ Saved per-image metrics → /content/drive/MyDrive/Drone AI/ModelRuns/UNet/OR/pretrain/eval_1112/test_detailed_metrics_smp.csv
# ✅ Saved summary JSON     → /content/drive/MyDrive/Drone AI/ModelRuns/UNet/OR/pretrain/eval_1112/test_summary_smp.json
#
# —— Summary ——
#            average_iou: 0.008286
#   average_boundary_iou: 0.006870
#       average_accuracy: 0.186424
#           average_dice: 0.016431
#      average_precision: 0.745175
#         average_recall: 0.008318

# %%
# !python eval-pretrain.py \
    --base-dir "/content/drive/MyDrive/Drone AI/DroneVision_Model_data/WA" \
    --out-dir "/content/drive/MyDrive/Drone AI/ModelRuns/UNet/WA/pretrain/evaleval_1113" \
    --batch-size 32 --img-size 512
# Out:
# [split] Using split = test
# ⚙️ Using SMP Unet (resnet34, imagenet) as pretrained baseline
# Eval: 100% 53/53 [00:20<00:00,  2.55it/s]
#
# ✅ Saved per-image metrics → /content/drive/MyDrive/Drone AI/ModelRuns/UNet/WA/pretrain/evaleval_1113/test_detailed_metrics_smp.csv
# ✅ Saved summary JSON     → /content/drive/MyDrive/Drone AI/ModelRuns/UNet/WA/pretrain/evaleval_1113/test_summary_smp.json
#
# —— Summary ——
#            average_iou: 0.005833
#   average_boundary_iou: 0.009455
#       average_accuracy: 0.251443
#           average_dice: 0.011593
#      average_precision: 0.713861
#         average_recall: 0.005850
